# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
# Looking in my directory for the data folder
# !ls
# Out:
# data
# student-checkpoint.ipynb

# %%
# Looking at the data files in the data folder
# !ls data
# Out:
# bom.movie_gross.csv
# im.db
# rt.movie_info.tsv
# rt.reviews.tsv
# tmdb.movies.csv
# tn.movie_budgets.csv

# %%
# Importing all the packages
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Opening 'bom.movie_gross.csv' file in pandas and naming it 'gross'
gross = pd.read_csv('data/bom.movie_gross.csv')
gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
# Getting info from the gross about amount of null values and the Dtype
gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# Getting all the aggregating functions from the gross data file
gross.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
# Looking at the sum of null values in the gross data file
gross.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
# Looking at the unique value counts in the 'studio' column in the gross data file
gross['studio'].value_counts()
# Out:
# IFC           166
# Uni.          147
# WB            140
# Fox           136
# Magn.         136
#              ...
# E1              1
# PI              1
# ELS             1
# PalT            1
# Synergetic      1
# Name: studio, Length: 257, dtype: int64

# %%
# Opening the 'rt.movie_info.tsv' file with pandas in the data folder and naming it 'rating'
rating = pd.read_csv('data/rt.movie_info.tsv', sep='\t')
rating
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
review = pd.read_table('data/rt.reviews.tsv', encoding='latin1')
review
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
rating
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
movie = pd.read_csv('data/tmdb.movies.csv')
movie
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
budget = pd.read_csv('data/tn.movie_budgets.csv')
budget
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
fm = pd.merge(movie, gross, how = 'inner', on = 'title').copy()
fm
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              4        [28, 878, 12]   27205                en
# 3              7      [16, 10751, 35]   10193                en
# 4              8      [16, 10751, 35]   20352                en
# ...          ...                  ...     ...               ...
# 2698       25090      [16, 10751, 12]  455842                en
# 2699       25148         [28, 12, 16]  332718                en
# 2700       25189                 [35]  498919                es
# 2701       25307                 [18]  470641                hi
# 2702       26409          [10749, 18]  551634                zh
#
#                      original_title  popularity release_date  \
# 0          How to Train Your Dragon      28.734   2010-03-26
# 1                        Iron Man 2      28.515   2010-05-07
# ...

# %%
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2703 entries, 0 to 2702
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2703 non-null   int64
#  1   genre_ids          2703 non-null   object
#  2   id                 2703 non-null   int64
#  3   original_language  2703 non-null   object
#  4   original_title     2703 non-null   object
#  5   popularity         2703 non-null   float64
#  6   release_date       2703 non-null   object
#  7   title              2703 non-null   object
#  8   vote_average       2703 non-null   float64
#  9   vote_count         2703 non-null   int64
#  10  studio             2702 non-null   object
#  11  domestic_gross     2682 non-null   float64
#  12  foreign_gross      1723 non-null   object
#  13  year               2703 non-null   int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 316.8+ KB

# %%
fm.loc[fm['Unnamed: 0'] == 2000]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, genre_ids, id, original_language, original_title, popularity, release_date, title, vote_average, vote_count, studio, domestic_gross, foreign_gross, year]
# Index: []

# %%
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2703 entries, 0 to 2702
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2703 non-null   int64
#  1   genre_ids          2703 non-null   object
#  2   id                 2703 non-null   int64
#  3   original_language  2703 non-null   object
#  4   original_title     2703 non-null   object
#  5   popularity         2703 non-null   float64
#  6   release_date       2703 non-null   object
#  7   title              2703 non-null   object
#  8   vote_average       2703 non-null   float64
#  9   vote_count         2703 non-null   int64
#  10  studio             2702 non-null   object
#  11  domestic_gross     2682 non-null   float64
#  12  foreign_gross      1723 non-null   object
#  13  year               2703 non-null   int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 316.8+ KB

# %%
fm['domestic_gross'].dropna(axis = 'index', how = 'any')
fm.dropna(subset = ['domestic_gross'], inplace=True)

# %%
fm['foreign_gross'] = pd.to_numeric(fm['foreign_gross'], errors='coerce')
fm['foreign_gross'].fillna(0, inplace=True)

# %%
fm['domestic_gross'] = fm['domestic_gross'].astype(int)
fm['foreign_gross'] = fm['foreign_gross'].astype(int)

# %%
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2682 entries, 0 to 2702
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2682 non-null   int64
#  1   genre_ids          2682 non-null   object
#  2   id                 2682 non-null   int64
#  3   original_language  2682 non-null   object
#  4   original_title     2682 non-null   object
#  5   popularity         2682 non-null   float64
#  6   release_date       2682 non-null   object
#  7   title              2682 non-null   object
#  8   vote_average       2682 non-null   float64
#  9   vote_count         2682 non-null   int64
#  10  studio             2681 non-null   object
#  11  domestic_gross     2682 non-null   int32
#  12  foreign_gross      2682 non-null   int32
#  13  year               2682 non-null   int64
# dtypes: float64(2), int32(2), int64(4), object(6)
# memory usage: 293.3+ KB

# %%
fm['worldwide_gross'] = fm['domestic_gross'] + fm['foreign_gross']

# %%
fm.sort_values(by=['worldwide_gross'], ascending=False).loc[fm['original_language'] == 'tr']
# Out:
#       Unnamed: 0 genre_ids      id original_language original_title  \
# 2168       20940      [99]  392011                tr           Kedi
# 2167       17643      [99]  392011                tr           Kedi
# 1836       14490      [18]  336804                tr        Mustang
#
#       popularity release_date    title  vote_average  vote_count studio  \
# 2168       8.982   2017-02-10     Kedi           7.5         106  Osci.
# 2167       8.982   2017-02-10     Kedi           7.5         106  Osci.
# 1836       7.459   2015-11-20  Mustang           8.0         755  Cohen
#
#       domestic_gross  foreign_gross  year  worldwide_gross
# 2168         2800000              0  2017          2800000
# 2167         2800000              0  2017          2800000
# 1836          845000              0  2015           845000

# %%
fm['original_language'].value_counts()
# Out:
# en    2142
# fr     123
# hi      59
# zh      48
# es      44
# ja      38
# ko      29
# de      24
# no      18
# it      16
# cn      15
# ru      13
# he      13
# da      12
# pt      11
# sv      10
# ro       8
# nl       7
# el       5
# pl       5
# th       5
# fa       4
# ta       4
# ar       4
# hu       4
# uk       3
# is       3
# tr       3
# mi       1
# ca       1
# te       1
# tl       1
# eu       1
# ka       1
# lt       1
# id       1
# et       1
# xx       1
# fi       1
# vi       1
# Name: original_language, dtype: int64

# %%
fm['original_language'].isna().sum()
# Out:
# 0

# %%
fm['popularity'].isna().sum()
# Out:
# 0

# %%
fm['original_language'].unique()
# Out:
# array(['en', 'es', 'sv', 'ja', 'ru', 'fr', 'hi', 'de', 'no', 'da', 'fi',
#        'it', 'zh', 'th', 'pt', 'cn', 'uk', 'ko', 'fa', 'hu', 'nl', 'el',
#        'pl', 'ro', 'he', 'xx', 'ta', 'et', 'ar', 'ka', 'id', 'is', 'tr',
#        'lt', 'mi', 'eu', 'tl', 'te', 'ca', 'vi'], dtype=object)

# %%
subset_60p = fm.loc[fm['popularity'] < 80]
value_counts = subset_60p['original_language'].value_counts()
lang_bar_df = subset_60p[subset_60p['original_language'].isin(value_counts[value_counts > 4].index)].groupby('original_language').median().sort_values(by = 'popularity', ascending = False).reset_index().head()

# %%
lang_bar_df
# Out:
#   original_language  Unnamed: 0        id  popularity  vote_average  \
# 0                en     11314.0  209276.0      9.5710           6.4
# 1                ja     17458.0  315846.0      9.0615           7.4
# 2                sv     16588.5  187789.5      7.8195           7.2
# 3                pl     17732.0  375742.0      7.5680           6.5
# 4                da      5595.5   95968.0      7.4825           7.0
#
#    vote_count  domestic_gross  foreign_gross    year  worldwide_gross
# 0       606.0      12100000.0      7700000.0  2014.0       22900000.0
# 1       194.0        468000.0            0.0  2016.0         687000.0
# 2       185.0        811500.0            0.0  2014.5         816000.0
# 3        88.0        102000.0            0.0  2017.0         102000.0
# 4       166.0        268500.0      1000000.0  2012.5        1313800.0

# %%
fig, ax = plt.subplots(figsize=(16,7))
sns.barplot(x = lang_bar_df['original_language'], y = lang_bar_df['popularity'])
sns.set_theme()
sns.set(font_scale=2)
fig.subplots_adjust(hspace=0.125, wspace=0.125)
ax.tick_params(axis='x', rotation=75)
ax.set_xlabel('Original Language')
ax.set_ylabel('Average Popularity')
ax.set_title('Top 5 Most Popular Languages for Movies');

# %%
fig, ax = plt.subplots(figsize=(16,7))
sns.barplot(x = subset_60p['original_language'], y = subset_60p['popularity'])
fig.subplots_adjust(hspace=0.125, wspace=0.125)
ax.tick_params(axis='x', rotation=75)
ax.set_xlabel('Original Language')
ax.set_ylabel('Average Popularity')
ax.set_title('Distribution of Average Popularity to Original Language');

# %%
fig, ax = plt.subplots(figsize=(20,9))
sns.barplot(x = fm['year'], y = fm['worldwide_gross'])
ax.set_xlabel('Year')
ax.set_ylabel('Worldwide Gross')
ax.set_title('Year Distribution of Worldwide Gross');

# %%
fm['studio'].unique()
# Out:
# array(['P/DW', 'Par.', 'WB', 'BV', 'Uni.', 'LGF', 'Sum.', 'Fox', 'Wein.',
#        'Sony', 'CBS', 'SGem', 'FoxS', 'Magn.', 'Anch.', 'SPC', 'Over.',
#        'MBox', 'W/Dim.', 'WB (NL)', 'Gold.', 'MGM', 'Focus', 'Drft.',
#        'RAtt.', 'IFC', 'ORF', 'ATO', 'Free', 'PDA', 'Hann.', 'FD',
#        'Rela.', 'Trib.', 'App.', 'Eros', 'Mira.', 'Mont.', 'FOAK', 'FM',
#        'NM', 'Osci.', 'Rog.', 'WHE', 'NGE', 'NFC', 'Strand', 'Indic.',
#        'ParV', 'Relbig.', 'First', 'UTV', 'Abr.', 'IW', 'Viv.', 'Arth.',
#        'FInd.', '3D', 'Zeit.', 'KL', 'CLS', 'ICir', 'Scre.', 'P4', 'LD',
#        'Lorb.', 'FCW', 'Vari.', 'IM', 'TriS', 'Imag.', 'MNE', 'NYer',
#        'SMod', 'CGld', 'MPFT', 'OMNI/FSR', 'RTWC', 'Vita.', 'Kino',
#        'Jan.', 'NeoC', 'SD', 'Rocket', nan, 'Yash', 'WGUSA', 'Libre',
#        'CL', 'Icar.', 'KC', 'EOne', 'Cohen', 'DF', 'SEG', 'A24',
#        'Grindstone', 'Pala.', 'Crnth', 'LG/S', 'AM', 'A23', 'FIP',
# ...

# %%
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2682 entries, 0 to 2702
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2682 non-null   int64
#  1   genre_ids          2682 non-null   object
#  2   id                 2682 non-null   int64
#  3   original_language  2682 non-null   object
#  4   original_title     2682 non-null   object
#  5   popularity         2682 non-null   float64
#  6   release_date       2682 non-null   object
#  7   title              2682 non-null   object
#  8   vote_average       2682 non-null   float64
#  9   vote_count         2682 non-null   int64
#  10  studio             2681 non-null   object
#  11  domestic_gross     2682 non-null   int32
#  12  foreign_gross      2682 non-null   int32
#  13  year               2682 non-null   int64
#  14  worldwide_gross    2682 non-null   int32
# dtypes: float64(2), int32(3), int64(4), object(6)
# ...

# %%
subset_300m = fm.loc[fm['worldwide_gross'] >= 300000000]

# %%
subset_300m
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              4        [28, 878, 12]   27205                en
# 3              7      [16, 10751, 35]   10193                en
# 4              8      [16, 10751, 35]   20352                en
# ...          ...                  ...     ...               ...
# 2592       23882          [18, 10749]  337167                en
# 2607       23915  [28, 53, 10752, 18]  460555                zh
# 2625       23961      [16, 12, 10751]  381719                en
# 2626       23969          [35, 10749]  458423                en
# 2689       24494         [12, 35, 14]  497984                zh
#
#                    original_title  popularity release_date  \
# 0        How to Train Your Dragon      28.734   2010-03-26
# 1                      Iron Man 2      28.515   2010-05-07
# ...

# %%
subset_300m['studio'].unique()
# Out:
# array(['P/DW', 'Par.', 'WB', 'BV', 'Uni.', 'Sum.', 'Fox', 'Wein.', 'FoxS',
#        'Sony', 'SGem', 'WB (NL)', 'LGF', 'LG/S', 'FR', 'FUN', 'UTV',
#        'WGUSA'], dtype=object)

# %%
subset_300m.sort_values(by = 'studio', ascending = False)
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 679         5189             [18, 37]   68718                en
# 13            25             [18, 36]   45269                en
# 2607       23915  [28, 53, 10752, 18]  460555                zh
# 981         7895             [27, 53]  138843                en
# 2016       17414       [27, 9648, 53]  259693                en
# ...          ...                  ...     ...               ...
# 1661       14215      [12, 16, 10751]  105864                en
# 2009       17401        [28, 12, 878]  330459                en
# 609        23817    [28, 12, 14, 878]  284054                en
# 608         3444             [28, 16]   86841                en
# 2052       17454  [12, 16, 35, 10751]  127380                en
#
#                     original_title  popularity release_date  \
# 679               Django Unchained      21.260   2012-12-25
# 13               The King's Speech      16.798   2010-09-06
# ...

# %%
fig, ax = plt.subplots(figsize=(16,7))
ax.bar(x = subset_300m['studio'], height = subset_300m['domestic_gross'], label='Domestic Gross', color='b')
ax.bar(x = subset_300m['studio'], height = subset_300m['foreign_gross'], label='Foreign Gross', color='r', bottom = subset_300m['domestic_gross'])
ax.legend()
ax.tick_params(axis='x', rotation=75)
ax.set_xlabel('Studios')
ax.set_ylabel('Gross (Billion)')
ax.set_title('Foreign vs. Domestic Gross For Each Studio');

# %%
fig, ax = plt.subplots(figsize=(16,7))
sns.boxplot(x = subset_300m['studio'], y = subset_300m['worldwide_gross'])
sns.set(font_scale=2)
ax.tick_params(axis='x', rotation=75)
ax.set_xlabel('Studios')
ax.set_ylabel('Worldwide Gross (Billion)')
ax.set_title('Average Worldwide Gross of Movie Studios (Studios Making Over 300M)');

# %%
fm.isna().sum()
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# studio               1
# domestic_gross       0
# foreign_gross        0
# year                 0
# worldwide_gross      0
# dtype: int64

# %%
review_rating = pd.merge(review, rating, how = 'inner', on = 'id').copy()
review_rating
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 1         3  It's an allegory in search of a meaning that n...      NaN
# 2         3  ... life lived in a bubble in financial dealin...      NaN
# 3         3  Continuing along a line introduced in last yea...      NaN
# 4         3             ... a perverse twist on neorealism...       NaN
# ...     ...                                                ...      ...
# 54427  2000  The real charm of this trifle is the deadpan c...      NaN
# 54428  2000                                                NaN      1/5
# 54429  2000                                                NaN      2/5
# 54430  2000                                                NaN    2.5/5
# 54431  2000                                                NaN      3/5
#
#         fresh             critic  top_critic         publisher  \
# ...

# %%
review_rating.loc[review_rating['id'] == 23961]
# Out:
# Empty DataFrame
# Columns: [id, review, rating_x, fresh, critic, top_critic, publisher, date, synopsis, rating_y, genre, director, writer, theater_date, dvd_date, currency, box_office, runtime, studio]
# Index: []

# %%
review_rating['rating_x'].isnull().value_counts()
# Out:
# False    40915
# True     13517
# Name: rating_x, dtype: int64

# %%
review_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54432 entries, 0 to 54431
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            54432 non-null  int64
#  1   review        48869 non-null  object
#  2   rating_x      40915 non-null  object
#  3   fresh         54432 non-null  object
#  4   critic        51710 non-null  object
#  5   top_critic    54432 non-null  int64
#  6   publisher     54123 non-null  object
#  7   date          54432 non-null  object
#  8   synopsis      54300 non-null  object
#  9   rating_y      54346 non-null  object
#  10  genre         54345 non-null  object
#  11  director      48992 non-null  object
#  12  writer        45206 non-null  object
#  13  theater_date  53206 non-null  object
#  14  dvd_date      53206 non-null  object
#  15  currency      33310 non-null  object
#  16  box_office    33310 non-null  object
#  17  runtime       53594 non-null  object
# ...

# %%
review_rating.dropna(subset = 'rating_x', inplace=True)

# %%
review_rating.dropna(subset = 'rating_y', inplace=True)

# %%
fig, ax = plt.subplots(figsize = (16,7))
sns.histplot(x = review_rating['rating_y'])
ax.set_xlabel('Rating')
ax.set_ylabel('Number of Movies')
ax.set_title('Amount of Movies Using Each Rating');

# %%
review_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40840 entries, 0 to 54431
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            40840 non-null  int64
#  1   review        35311 non-null  object
#  2   rating_x      40840 non-null  object
#  3   fresh         40840 non-null  object
#  4   critic        38864 non-null  object
#  5   top_critic    40840 non-null  int64
#  6   publisher     40613 non-null  object
#  7   date          40840 non-null  object
#  8   synopsis      40810 non-null  object
#  9   rating_y      40840 non-null  object
#  10  genre         40839 non-null  object
#  11  director      36700 non-null  object
#  12  writer        33931 non-null  object
#  13  theater_date  40015 non-null  object
#  14  dvd_date      40015 non-null  object
#  15  currency      25538 non-null  object
#  16  box_office    25538 non-null  object
#  17  runtime       40297 non-null  object
# ...

# %%
budget.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget    object
# domestic_gross       object
# worldwide_gross      object
# dtype: object

# %%
budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
budget['production_budget'] =budget['production_budget'].apply(lambda x: int(x.replace('$','').replace(',','')))

# %%
budget['domestic_gross'] =budget['domestic_gross'].apply(lambda x: int(x.replace('$','').replace(',','')))

# %%
budget['worldwide_gross'] =budget['worldwide_gross'].apply(lambda x: int(x.replace('$','').replace(',','')))

# %%
budget.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget     int64
# domestic_gross        int64
# worldwide_gross       int64
# dtype: object

# %%
budget['production_budget'].mean()
# Out:
# 31587757.0965064

# %%
budget['production_budget'].median()
# Out:
# 17000000.0

# %%
fig, ax = plt.subplots(figsize=(16,7))
ax.scatter(budget['production_budget'], budget['worldwide_gross'])
ax.set_xlabel('Production Budget (In 100M)')
ax.set_ylabel('Worldwide Gross (Billion)')
ax.set_title('Average Production Budget on Movies');

# %%
rating.dropna(axis=0, subset=['theater_date'], inplace=True)

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1201 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1201 non-null   int64
#  1   synopsis      1198 non-null   object
#  2   rating        1201 non-null   object
#  3   genre         1201 non-null   object
#  4   director      1083 non-null   object
#  5   writer        938 non-null    object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      334 non-null    object
#  9   box_office    334 non-null    object
#  10  runtime       1194 non-null   object
#  11  studio        464 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 122.0+ KB

# %%
rating['runtime'] = rating['runtime'].apply(lambda x: int(x.replace('minutes',''))if isinstance(x, str) else x)

# %%
mean_runtime = rating['runtime'].mean()
mean_runtime
# Out:
# 105.94388609715243

# %%
rating['runtime'].fillna(value=mean_runtime, inplace=True)

# %%
subset_2000 = rating[rating.theater_date.str[-4:].astype(int)>=2010]
year = subset_2000.theater_date.str.split(",").str[1].tolist()
year = [int(i) for i in year]
subset_2000
# Out:
#         id                                           synopsis rating  \
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 8       14  "Love Ranch" is a bittersweet love story that ...      R
# 15      22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 16      23  A fictional film set in the alluring world of ...      R
# 18      25  From ancient Japan's most enduring tale, the e...  PG-13
# ...    ...                                                ...    ...
# 1524  1960  SELMA is the story of a movement. The film chr...  PG-13
# 1530  1968  This holiday season, acclaimed filmmaker Camer...     PG
# 1536  1975  The year is 1953. A visiting archaeologist cal...     NR
# 1537  1976  Embrace of the Serpent features the encounter,...     NR
# 1542  1981  Money, Fame and the Knowledge of English. In I...     NR
#
#                                                   genre              director  \
# ...

# %%
fig, ax = plt.subplots(figsize=(16,7))
sns.barplot(x = subset_2000['rating'], y = subset_2000['runtime'])
ax.set_xlabel('Rating')
ax.set_ylabel('Runtime (Min)')
ax.set_title('Distribution of Rating and Runtime Since 2010');

# %%
rating
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 5        8  The year is 1942. As the Allies unite overseas...     PG
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
fm
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              4        [28, 878, 12]   27205                en
# 3              7      [16, 10751, 35]   10193                en
# 4              8      [16, 10751, 35]   20352                en
# ...          ...                  ...     ...               ...
# 2698       25090      [16, 10751, 12]  455842                en
# 2699       25148         [28, 12, 16]  332718                en
# 2700       25189                 [35]  498919                es
# 2701       25307                 [18]  470641                hi
# 2702       26409          [10749, 18]  551634                zh
#
#                      original_title  popularity release_date  \
# 0          How to Train Your Dragon      28.734   2010-03-26
# 1                        Iron Man 2      28.515   2010-05-07
# ...

# %%
conn = sqlite3.connect('data/im.db')
cursor_obj = conn.cursor()

# %%
# %%bash
#
# sqlite3 data/im.db
# .tables
# Out:
# directors      movie_akas     movie_ratings  principals
# known_for      movie_basics   persons        writers

# %%
directors = pd.read_sql("""SELECT * FROM directors;""",conn)
directors
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0462036   nm1940585
# 2       tt0835418   nm0151540
# 3       tt0835418   nm0151540
# 4       tt0878654   nm0089502
# ...           ...         ...
# 291169  tt8999974  nm10122357
# 291170  tt9001390   nm6711477
# 291171  tt9001494  nm10123242
# 291172  tt9001494  nm10123248
# 291173  tt9004986   nm4993825
#
# [291174 rows x 2 columns]

# %%
movie_akas = pd.read_sql("""SELECT * FROM movie_akas;""",conn)
movie_akas
# Out:
#          movie_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru   None
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención   None
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...

# %%
movie_ratings = pd.read_sql("""SELECT * FROM movie_ratings;""",conn)
movie_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
principals = pd.read_sql("""SELECT * FROM principals;""",conn)
principals
# Out:
#           movie_id  ordering   person_id  category       job  \
# 0        tt0111414         1   nm0246005     actor      None
# 1        tt0111414         2   nm0398271  director      None
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor      None
# 4        tt0323808         1   nm3579312   actress      None
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor      None
# 1028182  tt9692684         2   nm4929530      self      None
# 1028183  tt9692684         3  nm10441594  director      None
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                        None
# 2                        None
# 3                        None
# 4            ["Beth Boothby"]
# ...                       ...
# ...

# %%
known_for = pd.read_sql("""SELECT * FROM known_for;""",conn)
known_for
# Out:
#          person_id   movie_id
# 0        nm0061671  tt0837562
# 1        nm0061671  tt2398241
# 2        nm0061671  tt0844471
# 3        nm0061671  tt0118553
# 4        nm0061865  tt0896534
# ...            ...        ...
# 1638255  nm9990690  tt9090932
# 1638256  nm9990690  tt8737130
# 1638257  nm9991320  tt8734436
# 1638258  nm9991320  tt9615610
# 1638259  nm9993380  tt8743182
#
# [1638260 rows x 2 columns]

# %%
movie_basics = pd.read_sql("""SELECT * FROM movie_basics;""", conn)
movie_basics
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
run_rate = pd.merge(movie_basics, movie_ratings, how = 'inner', on = 'movie_id')
run_rate
# Out:
#         movie_id                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
run_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   start_year       73856 non-null  int64
#  4   runtime_minutes  66236 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73856 non-null  float64
#  7   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.1+ MB

# %%
run_rate.describe()
# Out:
#          start_year  runtime_minutes  averagerating      numvotes
# count  73856.000000     66236.000000   73856.000000  7.385600e+04
# mean    2014.276132        94.654040       6.332729  3.523662e+03
# std        2.614807       208.574111       1.474978  3.029402e+04
# min     2010.000000         3.000000       1.000000  5.000000e+00
# 25%     2012.000000        81.000000       5.500000  1.400000e+01
# 50%     2014.000000        91.000000       6.500000  4.900000e+01
# 75%     2016.000000       104.000000       7.400000  2.820000e+02
# max     2019.000000     51420.000000      10.000000  1.841066e+06

# %%
run_rate.sort_values(by=['runtime_minutes'], ascending=False)
# Out:
#         movie_id               primary_title              original_title  \
# 70280  tt8273150                   Logistics                   Logistics
# 27683  tt2659636        Modern Times Forever        Modern Times Forever
# 15171  tt2008009                   The Clock                   The Clock
# 71441  tt8677246       Bullfighting Memories       Bullfighting Memories
# 72424  tt9047474                     La flor                     La flor
# ...          ...                         ...                         ...
# 73828  tt9899290    Band Together with Logic    Band Together with Logic
# 73830  tt9899850               The Agitation                   Ashoftegi
# 73844  tt9905796                July Kaatril                July Kaatril
# 73853  tt9914642                   Albatross                   Albatross
# 73854  tt9914942  La vida sense la Sara Amat  La vida sense la Sara Amat
#
#        start_year  runtime_minutes                 genres  averagerating  \
# ...

# %%
run_rate['runtime_minutes'].isna().sum()
# Out:
# 7620

# %%
mean_run = run_rate['runtime_minutes'].mean()

# %%
run_rate['runtime_minutes'].fillna(value=mean_run, inplace=True)

# %%
run_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73856 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   start_year       73856 non-null  int64
#  4   runtime_minutes  73856 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73856 non-null  float64
#  7   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.1+ MB

# %%
run_rate
# Out:
#                 movie_id                    primary_title  \
# 0              tt0063540                        Sunghursh
# 1              tt0066787  One Day Before the Rainy Season
# 2              tt0069049       The Other Side of the Wind
# 3              tt0069204                  Sabse Bada Sukh
# 4              tt0100275         The Wandering Soap Opera
# ...                  ...                              ...
# 73852          tt9914286                Sokagin Çocuklari
# 73853          tt9914642                        Albatross
# 73854          tt9914942       La vida sense la Sara Amat
# 73855          tt9916160                       Drømmeland
# averagerating        NaN                              NaN
#
#                            original_title  start_year  runtime_minutes  \
# 0                               Sunghursh      2013.0        175.00000
# 1                         Ashad Ka Ek Din      2019.0        114.00000
# ...

# %%
subset_run = run_rate.loc[run_rate['runtime_minutes'] < 200]
subset_run
# Out:
#         movie_id                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
subset_run.loc['averagerating'] = subset_run['averagerating'].round(decimals=0).copy()

# %%
#subset_run.dropna(subset='averagerating', inplace=True)

# %%
#subset_run.loc['averagerating'] = subset_run['averagerating'].astype(int)

# %%
#subset_run_copy = subset_run.copy()
#subset_run_copy.loc['averagerating'] = subset_run_copy['averagerating'].round(decimals=0)

# %%
subset_run['averagerating']
# Out:
# 0                7.0
# 1                7.2
# 2                6.9
# 3                6.1
# 4                6.5
#                 ...
# 73852            8.7
# 73853            8.5
# 73854            6.6
# 73855            6.5
# averagerating    NaN
# Name: averagerating, Length: 73694, dtype: float64

# %%
runt = subset_run['runtime_minutes']
ar = subset_run['averagerating']

# %%
subset_run.describe()
# Out:
#          start_year  runtime_minutes  averagerating      numvotes
# count  73693.000000     73693.000000   73693.000000  7.369300e+04
# mean    2014.275983        93.327532       6.330502  3.529457e+03
# std        2.614654        20.870257       1.474217  3.032605e+04
# min     2010.000000         3.000000       1.000000  5.000000e+00
# 25%     2012.000000        83.000000       5.500000  1.400000e+01
# 50%     2014.000000        93.000000       6.500000  4.900000e+01
# 75%     2016.000000       101.000000       7.400000  2.820000e+02
# max     2019.000000       199.000000      10.000000  1.841066e+06

# %%
fig, ax = plt.subplots(figsize=(16,9))
sns.pointplot(x = ar, y = runt, color = 'r')
ax.set_xlabel('Score (Out of 10)')
ax.set_ylabel('Runtime (Min)')
ax.set_title('Average Runtime for Each Score');

# %%
persons = pd.read_sql("""SELECT * FROM persons;""",conn)
persons
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
writers = pd.read_sql("""SELECT * FROM writers;""",conn)
writers
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0438973   nm0175726
# 2       tt0438973   nm1802864
# 3       tt0462036   nm1940585
# 4       tt0835418   nm0310087
# ...           ...         ...
# 255868  tt8999892  nm10122246
# 255869  tt8999974  nm10122357
# 255870  tt9001390   nm6711477
# 255871  tt9004986   nm4993825
# 255872  tt9010172   nm8352242
#
# [255873 rows x 2 columns]

# %%
# %%bash
#
# sqlite3 data/im.db
# .schema movie_akas
# Out:
# CREATE TABLE IF NOT EXISTS "movie_akas" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "title" TEXT,
#   "region" TEXT,
#   "language" TEXT,
#   "types" TEXT,
#   "attributes" TEXT,
#   "is_original_title" REAL
# );

# %%
fm
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              4        [28, 878, 12]   27205                en
# 3              7      [16, 10751, 35]   10193                en
# 4              8      [16, 10751, 35]   20352                en
# ...          ...                  ...     ...               ...
# 2698       25090      [16, 10751, 12]  455842                en
# 2699       25148         [28, 12, 16]  332718                en
# 2700       25189                 [35]  498919                es
# 2701       25307                 [18]  470641                hi
# 2702       26409          [10749, 18]  551634                zh
#
#                      original_title  popularity release_date  \
# 0          How to Train Your Dragon      28.734   2010-03-26
# 1                        Iron Man 2      28.515   2010-05-07
# ...

# %%
review_rating
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 6         3  Quickly grows repetitive and tiresome, meander...        C
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# 11        3  While not one of Cronenberg's stronger films, ...       B-
# 12        3  Robert Pattinson works mighty hard to make Cos...      2/4
# ...     ...                                                ...      ...
# 54424  2000  Dawdles and drags when it should pop; it doesn...    1.5/5
# 54428  2000                                                NaN      1/5
# 54429  2000                                                NaN      2/5
# 54430  2000                                                NaN    2.5/5
# 54431  2000                                                NaN      3/5
#
#         fresh             critic  top_critic           publisher  \
# ...

# %%
review_rating['genre'].isna().sum()
# Out:
# 1

# %%
review_rating.dropna(subset = ['genre'], inplace=True)

# %%
review_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40839 entries, 0 to 54431
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            40839 non-null  int64
#  1   review        35310 non-null  object
#  2   rating_x      40839 non-null  object
#  3   fresh         40839 non-null  object
#  4   critic        38863 non-null  object
#  5   top_critic    40839 non-null  int64
#  6   publisher     40612 non-null  object
#  7   date          40839 non-null  object
#  8   synopsis      40809 non-null  object
#  9   rating_y      40839 non-null  object
#  10  genre         40839 non-null  object
#  11  director      36699 non-null  object
#  12  writer        33930 non-null  object
#  13  theater_date  40015 non-null  object
#  14  dvd_date      40015 non-null  object
#  15  currency      25538 non-null  object
#  16  box_office    25538 non-null  object
#  17  runtime       40296 non-null  object
# ...

# %%
review_rating['genre'] = review_rating['genre'].apply(lambda x: str(x.replace('|',',').replace('and',',').replace(' , ',',')))

# %%
review_rating
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 6         3  Quickly grows repetitive and tiresome, meander...        C
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# 11        3  While not one of Cronenberg's stronger films, ...       B-
# 12        3  Robert Pattinson works mighty hard to make Cos...      2/4
# ...     ...                                                ...      ...
# 54424  2000  Dawdles and drags when it should pop; it doesn...    1.5/5
# 54428  2000                                                NaN      1/5
# 54429  2000                                                NaN      2/5
# 54430  2000                                                NaN    2.5/5
# 54431  2000                                                NaN      3/5
#
#         fresh             critic  top_critic           publisher  \
# ...

# %%
review_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40839 entries, 0 to 54431
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            40839 non-null  int64
#  1   review        35310 non-null  object
#  2   rating_x      40839 non-null  object
#  3   fresh         40839 non-null  object
#  4   critic        38863 non-null  object
#  5   top_critic    40839 non-null  int64
#  6   publisher     40612 non-null  object
#  7   date          40839 non-null  object
#  8   synopsis      40809 non-null  object
#  9   rating_y      40839 non-null  object
#  10  genre         40839 non-null  object
#  11  director      36699 non-null  object
#  12  writer        33930 non-null  object
#  13  theater_date  40015 non-null  object
#  14  dvd_date      40015 non-null  object
#  15  currency      25538 non-null  object
#  16  box_office    25538 non-null  object
#  17  runtime       40296 non-null  object
# ...

# %%
#fm.sort_values(by=['worldwide_gross'], ascending=False).loc[fm['original_language'] == 'tr']

# %%
#lang_bar_df = subset_60p[subset_60p['original_language'].isin(value_counts[value_counts > 4].index)].groupby('original_language').median().sort_values(by = 'popularity', ascending = False).reset_index().head()

# %%
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2682 entries, 0 to 2702
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2682 non-null   int64
#  1   genre_ids          2682 non-null   object
#  2   id                 2682 non-null   int64
#  3   original_language  2682 non-null   object
#  4   original_title     2682 non-null   object
#  5   popularity         2682 non-null   float64
#  6   release_date       2682 non-null   object
#  7   title              2682 non-null   object
#  8   vote_average       2682 non-null   float64
#  9   vote_count         2682 non-null   int64
#  10  studio             2681 non-null   object
#  11  domestic_gross     2682 non-null   int32
#  12  foreign_gross      2682 non-null   int32
#  13  year               2682 non-null   int64
#  14  worldwide_gross    2682 non-null   int32
# dtypes: float64(2), int32(3), int64(4), object(6)
# ...

# %%
genre_id = {28:'Action', 12:'Adventure', 16:'Animation', 35:'Comedy', 80:'Crime',
            99:'Documentary', 18:'Drama', 10751:'Family', 14:'Fantasy', 36:'History',
            27:'Horror', 10402:'Music', 9648:'Mystery', 10749:'Romance',
            878:'Science Fiction', 10770:'TV Movie', 53:'Thriller', 10752:'War',
            37:'Western'}
print(genre_id.keys())
# Out:
# dict_keys([28, 12, 16, 35, 80, 99, 18, 10751, 14, 36, 27, 10402, 9648, 10749, 878, 10770, 53, 10752, 37])

# %%
fm['genre_ids'] = fm['genre_ids'].apply(lambda x: x if not pd.isna(x) else None)
import ast
fm_genres = fm[pd.notnull(fm['genre_ids'])]
fm_genres['genre_ids'] = fm_genres['genre_ids'].apply(lambda x: ast.literal_eval(x))
fm_genres['genre'] = fm_genres['genre_ids'].apply(lambda x: [genre_id[g] for g in x])
fm_genres['genre'] = fm_genres['genre'].apply(lambda x: ', '.join(x))
fm_genres
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              4        [28, 878, 12]   27205                en
# 3              7      [16, 10751, 35]   10193                en
# 4              8      [16, 10751, 35]   20352                en
# ...          ...                  ...     ...               ...
# 2698       25090      [16, 10751, 12]  455842                en
# 2699       25148         [28, 12, 16]  332718                en
# 2700       25189                 [35]  498919                es
# 2701       25307                 [18]  470641                hi
# 2702       26409          [10749, 18]  551634                zh
#
#                      original_title  popularity release_date  \
# 0          How to Train Your Dragon      28.734   2010-03-26
# 1                        Iron Man 2      28.515   2010-05-07
# ...

# %%
fm_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2682 entries, 0 to 2702
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2682 non-null   int64
#  1   genre_ids          2682 non-null   object
#  2   id                 2682 non-null   int64
#  3   original_language  2682 non-null   object
#  4   original_title     2682 non-null   object
#  5   popularity         2682 non-null   float64
#  6   release_date       2682 non-null   object
#  7   title              2682 non-null   object
#  8   vote_average       2682 non-null   float64
#  9   vote_count         2682 non-null   int64
#  10  studio             2681 non-null   object
#  11  domestic_gross     2682 non-null   int32
#  12  foreign_gross      2682 non-null   int32
#  13  year               2682 non-null   int64
#  14  worldwide_gross    2682 non-null   int32
#  15  genre              2682 non-null   object
# ...

# %%
review_rating
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 6         3  Quickly grows repetitive and tiresome, meander...        C
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# 11        3  While not one of Cronenberg's stronger films, ...       B-
# 12        3  Robert Pattinson works mighty hard to make Cos...      2/4
# ...     ...                                                ...      ...
# 54424  2000  Dawdles and drags when it should pop; it doesn...    1.5/5
# 54428  2000                                                NaN      1/5
# 54429  2000                                                NaN      2/5
# 54430  2000                                                NaN    2.5/5
# 54431  2000                                                NaN      3/5
#
#         fresh             critic  top_critic           publisher  \
# ...

# %%
print(fm['genre_ids'].dtype)
# Out:
# object

# %%
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2682 entries, 0 to 2702
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2682 non-null   int64
#  1   genre_ids          2682 non-null   object
#  2   id                 2682 non-null   int64
#  3   original_language  2682 non-null   object
#  4   original_title     2682 non-null   object
#  5   popularity         2682 non-null   float64
#  6   release_date       2682 non-null   object
#  7   title              2682 non-null   object
#  8   vote_average       2682 non-null   float64
#  9   vote_count         2682 non-null   int64
#  10  studio             2681 non-null   object
#  11  domestic_gross     2682 non-null   int32
#  12  foreign_gross      2682 non-null   int32
#  13  year               2682 non-null   int64
#  14  worldwide_gross    2682 non-null   int32
# dtypes: float64(2), int32(3), int64(4), object(6)
# ...

# %%
#fm['genre_ids'] = pd.to_numeric(fm['genre_ids'], errors='coerce')
#fm['genre_ids'] = fm['genre_ids'].astype(int)

# %%
#fm = fm.explode('genre_ids')
#print(fm['genre_ids'].unique())
#print(genre_id.keys())

# %%
#print(fm['genre_ids'].apply(lambda x: [i for i in x]).unique())
#print(genre_id.keys())

# %%
#def map_genres(genre_list):
    #return [genre_id.get(g, 'Unknown') for g in genre_list]

#fm['genre_name'] = fm['genre_ids'].apply(map_genres)

# %%
fm
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              4        [28, 878, 12]   27205                en
# 3              7      [16, 10751, 35]   10193                en
# 4              8      [16, 10751, 35]   20352                en
# ...          ...                  ...     ...               ...
# 2698       25090      [16, 10751, 12]  455842                en
# 2699       25148         [28, 12, 16]  332718                en
# 2700       25189                 [35]  498919                es
# 2701       25307                 [18]  470641                hi
# 2702       26409          [10749, 18]  551634                zh
#
#                      original_title  popularity release_date  \
# 0          How to Train Your Dragon      28.734   2010-03-26
# 1                        Iron Man 2      28.515   2010-05-07
# ...

# %%
fm_genres
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              4        [28, 878, 12]   27205                en
# 3              7      [16, 10751, 35]   10193                en
# 4              8      [16, 10751, 35]   20352                en
# ...          ...                  ...     ...               ...
# 2698       25090      [16, 10751, 12]  455842                en
# 2699       25148         [28, 12, 16]  332718                en
# 2700       25189                 [35]  498919                es
# 2701       25307                 [18]  470641                hi
# 2702       26409          [10749, 18]  551634                zh
#
#                      original_title  popularity release_date  \
# 0          How to Train Your Dragon      28.734   2010-03-26
# 1                        Iron Man 2      28.515   2010-05-07
# ...

# %%
#fm_genres['year'] = fm_genres.release_date.str.split("-").str[0].tolist()

# %%
review_rating['year'] = review_rating.date.str.split(",").str[1].tolist()
#year = [int(i) for i in year]

# %%
review_rating.dropna(subset = ['theater_date'], inplace=True)

# %%
review_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40015 entries, 0 to 54431
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            40015 non-null  int64
#  1   review        34691 non-null  object
#  2   rating_x      40015 non-null  object
#  3   fresh         40015 non-null  object
#  4   critic        38090 non-null  object
#  5   top_critic    40015 non-null  int64
#  6   publisher     39793 non-null  object
#  7   date          40015 non-null  object
#  8   synopsis      40008 non-null  object
#  9   rating_y      40015 non-null  object
#  10  genre         40015 non-null  object
#  11  director      36004 non-null  object
#  12  writer        33308 non-null  object
#  13  theater_date  40015 non-null  object
#  14  dvd_date      40015 non-null  object
#  15  currency      25459 non-null  object
#  16  box_office    25459 non-null  object
#  17  runtime       39481 non-null  object
# ...

# %%
review_rating["theater_date"] = pd.to_datetime(review_rating["theater_date"], format= '%b %d, %Y').dt.strftime('%Y-%m-%d')

# %%
filtered_rating = review_rating.drop_duplicates(subset='synopsis')

# %%
filtered_rating
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 164       5  Charming tale of songwriter finding her voice ...      4/5
# 186       6  Though directed with machine-like precision by...    2.5/5
# 243       8  Great boy-and-dog tale, but be prepared for te...      4/5
# 318      10  It won't stick with you forever, but you will ...      3/5
# ...     ...                                                ...      ...
# 54175  1996  This is a good-looking film, and Jackson is ju...        B
# 54318  1997  It ultimately fails because it lacks sufficien...        C
# 54346  1998                 Better than average Elvis vehicle.      3/5
# 54351  1999  The Sandlot is just a fun, funny film that hol...       B+
# 54394  2000  I keep renting Jean Reno films and I'm beginni...      2/5
#
#         fresh           critic  top_critic                        publisher  \
# ...

# %%
review_rating
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 6         3  Quickly grows repetitive and tiresome, meander...        C
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# 11        3  While not one of Cronenberg's stronger films, ...       B-
# 12        3  Robert Pattinson works mighty hard to make Cos...      2/4
# ...     ...                                                ...      ...
# 54424  2000  Dawdles and drags when it should pop; it doesn...    1.5/5
# 54428  2000                                                NaN      1/5
# 54429  2000                                                NaN      2/5
# 54430  2000                                                NaN    2.5/5
# 54431  2000                                                NaN      3/5
#
#         fresh             critic  top_critic           publisher  \
# ...

# %%
filtered_rating.rename(columns={'theater_date': 'release_date'}, inplace=True)
# Out:
# C:\Users\srini\AppData\Local\Temp\ipykernel_17396\170961130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_rating.rename(columns={'theater_date': 'release_date'}, inplace=True)

# %%
filtered_rating
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 164       5  Charming tale of songwriter finding her voice ...      4/5
# 186       6  Though directed with machine-like precision by...    2.5/5
# 243       8  Great boy-and-dog tale, but be prepared for te...      4/5
# 318      10  It won't stick with you forever, but you will ...      3/5
# ...     ...                                                ...      ...
# 54175  1996  This is a good-looking film, and Jackson is ju...        B
# 54318  1997  It ultimately fails because it lacks sufficien...        C
# 54346  1998                 Better than average Elvis vehicle.      3/5
# 54351  1999  The Sandlot is just a fun, funny film that hol...       B+
# 54394  2000  I keep renting Jean Reno films and I'm beginni...      2/5
#
#         fresh           critic  top_critic                        publisher  \
# ...

# %%
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2682 entries, 0 to 2702
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2682 non-null   int64
#  1   genre_ids          2682 non-null   object
#  2   id                 2682 non-null   int64
#  3   original_language  2682 non-null   object
#  4   original_title     2682 non-null   object
#  5   popularity         2682 non-null   float64
#  6   release_date       2682 non-null   object
#  7   title              2682 non-null   object
#  8   vote_average       2682 non-null   float64
#  9   vote_count         2682 non-null   int64
#  10  studio             2681 non-null   object
#  11  domestic_gross     2682 non-null   int32
#  12  foreign_gross      2682 non-null   int32
#  13  year               2682 non-null   int64
#  14  worldwide_gross    2682 non-null   int32
# dtypes: float64(2), int32(3), int64(4), object(6)
# ...

# %%
review_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40015 entries, 0 to 54431
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            40015 non-null  int64
#  1   review        34691 non-null  object
#  2   rating_x      40015 non-null  object
#  3   fresh         40015 non-null  object
#  4   critic        38090 non-null  object
#  5   top_critic    40015 non-null  int64
#  6   publisher     39793 non-null  object
#  7   date          40015 non-null  object
#  8   synopsis      40008 non-null  object
#  9   rating_y      40015 non-null  object
#  10  genre         40015 non-null  object
#  11  director      36004 non-null  object
#  12  writer        33308 non-null  object
#  13  theater_date  40015 non-null  object
#  14  dvd_date      40015 non-null  object
#  15  currency      25459 non-null  object
#  16  box_office    25459 non-null  object
#  17  runtime       39481 non-null  object
# ...

# %%
fm_genres
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              4        [28, 878, 12]   27205                en
# 3              7      [16, 10751, 35]   10193                en
# 4              8      [16, 10751, 35]   20352                en
# ...          ...                  ...     ...               ...
# 2698       25090      [16, 10751, 12]  455842                en
# 2699       25148         [28, 12, 16]  332718                en
# 2700       25189                 [35]  498919                es
# 2701       25307                 [18]  470641                hi
# 2702       26409          [10749, 18]  551634                zh
#
#                      original_title  popularity release_date  \
# 0          How to Train Your Dragon      28.734   2010-03-26
# 1                        Iron Man 2      28.515   2010-05-07
# ...

# %%
rating_lang = pd.merge(fm_genres, filtered_rating, how="inner", on=['genre', 'release_date'])
rating_lang
# Out:
#     Unnamed: 0 genre_ids    id_x original_language  \
# 0          333      [35]   38778                en
# 1         4728      [18]   81658                fr
# 2         5330      [18]  112336                en
# 3         7945      [18]  103663                da
# 4         8335      [18]  128215                en
# 5         8022      [18]  179144                it
# 6         8193      [18]  192132                en
# 7        11383      [18]  192132                en
# 8        11548      [18]  244517                en
# 9         8213      [18]  194101                en
# 10       11205      [18]  157832                en
# 11       11294      [18]  253331                en
# 12       14436      [18]  253331                en
# 13       11342      [35]  214030                en
# 14       12214      [35]  166085                es
# 15       11553      [27]   79316                en
# 16       14214      [35]  214756                en
# ...

# %%
rating_lang
# Out:
#     Unnamed: 0 genre_ids    id_x original_language  \
# 0          333      [35]   38778                en
# 1         4728      [18]   81658                fr
# 2         5330      [18]  112336                en
# 3         7945      [18]  103663                da
# 4         8335      [18]  128215                en
# 5         8022      [18]  179144                it
# 6         8193      [18]  192132                en
# 7        11383      [18]  192132                en
# 8        11548      [18]  244517                en
# 9         8213      [18]  194101                en
# 10       11205      [18]  157832                en
# 11       11294      [18]  253331                en
# 12       14436      [18]  253331                en
# 13       11342      [35]  214030                en
# 14       12214      [35]  166085                es
# 15       11553      [27]   79316                en
# 16       14214      [35]  214756                en
# ...

# %%
rating_lang['original_language'].unique()
# Out:
# array(['en', 'fr', 'da', 'it', 'es', 'tr'], dtype=object)

# %%
fig, ax = plt.subplots(figsize = (16,7))
sns.histplot(x = rating_lang['rating_y'], hue = rating_lang['original_language'])
plt.legend(title='Language', loc = 'upper right', labels=['Turkish', 'French', 'Danish', 'Italian', 'Spanish', 'English'])
ax.set_xlabel('Rating')
ax.set_ylabel('Number of Movies')
ax.set_title('Amount of Movies Using Each Rating');
